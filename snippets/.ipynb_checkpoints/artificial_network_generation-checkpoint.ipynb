# %% [markdown]
# ## Import libs, set paths and load params

# %%
import os
import numpy as np
import pandas as pd
import sys
import csv
sys.path.insert(0, "../src")
ART_NET_PATH = "../networks"

import auxilary_functions as f
from generation_algorithm import *
from copy import deepcopy
import networkx as nx
from time import sleep
import statistics
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load Yeast Tnet and select the FFL-based component

# %%
interaction_matrix = f.get_interaction_matrix(cfg)

# %time
motifs, counter = f.motif_search(cfg, interaction_matrix, batch_size=10000)
motifs_orig = motifs["030T"]
counter

ffl_nodes = list(set(sum([list(map(int, x.split("_"))) for x in motifs_orig], [])))
interaction_matrix_ffl = np.zeros((len(ffl_nodes), len(ffl_nodes)))
for motif in motifs_orig:
    motif = f.split_motif(motif)
    motif_new = list(ffl_nodes.index(x) for x in motif)
    interaction_matrix_ffl[np.ix_(motif_new, motif_new)] = \
    interaction_matrix[np.ix_(motif, motif)]
interaction_matrix_ffl.shape, interaction_matrix_ffl.sum()

# Vertex-based motif network on FFL
motifs_network = f.build_vmn(motifs_orig, verbose=True)
V = nx.Graph(motifs_network)
nx.is_connected(V)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 4.05 µs
# 100%|██████████| 5676765/5676765 [00:18<00:00, 311350.27it/s]
# True

# %%
substrate_matrix = get_network_nucleus(
        interaction_matrix, motifs=motifs_orig, motifs_network=motifs_network, min_size=30
    )

substrate_matrix_t = substrate_matrix.transpose()
substrate_matrix_graph = nx.DiGraph(substrate_matrix_t)
nx.draw(substrate_matrix_graph, node_size = 5, edge_color = 'gray')

# %%
substrate_matrix_graph.out_degree()
# Out:
# OutDegreeView({0: 0, 1: 13, 2: 1, 3: 0, 4: 7, 5: 0, 6: 11, 7: 1, 8: 7, 9: 0, 10: 0, 11: 3, 12: 0, 13: 0, 14: 0, 15: 0, 16: 0, 17: 0, 18: 3, 19: 3, 20: 0, 21: 0, 22: 2, 23: 1, 24: 0, 25: 0, 26: 1, 27: 0, 28: 0, 29: 1})

# %%
substrate_matrix_graph.in_degree()
# Out:
# InDegreeView({0: 2, 1: 1, 2: 1, 3: 3, 4: 0, 5: 2, 6: 5, 7: 4, 8: 2, 9: 2, 10: 2, 11: 1, 12: 2, 13: 3, 14: 2, 15: 2, 16: 2, 17: 2, 18: 0, 19: 1, 20: 2, 21: 2, 22: 0, 23: 1, 24: 2, 25: 2, 26: 1, 27: 2, 28: 2, 29: 1})

# %% [markdown]
# ## Topology stats

# %%
def collect_topology_stats(growth_pace_vec, matrix_size_vec, initial_size_vec, barabasi_num_vec):
    network_topology_stats = {}
    #import resource
    
    for growth_pace_num in growth_pace_vec:
        for final_size in matrix_size_vec:
            for initial_size in initial_size_vec:
                for barabasi_num in barabasi_num_vec:
                
                    #generate network
                    artificial_matrix_ffl = generate_artificial_network(
                        interaction_matrix, motifs=motifs_orig, motifs_network=motifs_network,
                        nucleus_size=initial_size, network_size=final_size, growth_pace=growth_pace_num,
                        reference_matrix=interaction_matrix_ffl, growth_barabasi = barabasi_num, sparsity=3)
                    
                    ffl_perc = artificial_matrix_ffl[3]
                    sparsity = artificial_matrix_ffl[2]
                    time_spent = artificial_matrix_ffl[1]
                    artificial_matrix_ffl = artificial_matrix_ffl[0]

                    #GS-to-Networkx format conversion
                    art_matrix = artificial_matrix_ffl.transpose()

                    if not os.path.exists(ART_NET_PATH):
                            os.mkdir(ART_NET_PATH)
                    joblib.dump(
                            art_matrix, os.path.join(ART_NET_PATH,'_'+f"test{art_matrix.shape[0]}.gz")

                    )

                    #create edgelist
                    D1 = nx.DiGraph(art_matrix)
                    nx.write_edgelist(D1, os.path.join(ART_NET_PATH, "test.tsv"), data=False)

                    #analyze network
                    #network_test = f.read_df_as_network(os.path.join(ART_NET_PATH, "test.tsv"))
                    #diameter = nx.diameter(network_test)
                    #shortest_path = nx.average_shortest_path_length(network_test)

                    #collect stats
                    #key_to_dic = '_'.join(str(x) for x in [final_size,initial_size,growth_pace_num,barabasi_num])
                    #list_with_stats = [final_size, initial_size, sparsity,
                    #                   np.round(shortest_path, 4), diameter, growth_pace_num, barabasi_num, ffl_perc, time_spent]
                    #network_topology_stats[key_to_dic] = list_with_stats

    return network_topology_stats, artificial_matrix_ffl

# %%
dict_with_stats, matrix = collect_topology_stats([0.4],[500],[30],[0.3])
# Out:
# Nucleus matrix shape: (30, 30)
#
#
# num of iterations: 1
# ffl-components size: 30
# num of nodes: 0
# memory usage (MB): 1054.666752
# num of iterations: 2
# ffl-components size: 31
# num of nodes: 0
# memory usage (MB): 1054.666752
# num of iterations: 3
# ffl-components size: 31
# num of nodes: 3
# memory usage (MB): 1054.666752
# num of iterations: 4
# ffl-components size: 31
# num of nodes: 5
# memory usage (MB): 1054.666752
# num of iterations: 5
# ffl-components size: 31
# num of nodes: 8
# memory usage (MB): 1054.666752
# num of iterations: 6
# ffl-components size: 31
# num of nodes: 10
# memory usage (MB): 1054.666752
# num of iterations: 7
# ffl-components size: 31
# num of nodes: 10
# memory usage (MB): 1054.666752
# num of iterations: 8
# ffl-components size: 31
# num of nodes: 12
# memory usage (MB): 1054.666752
# num of iterations: 9
# ffl-components size: 31
# num of nodes: 14
# memory usage (MB): 1054.666752
# num of iterations: 10
# ffl-components size: 31
# num of nodes: 16
# memory usage (MB): 1054.666752
# num of iterations: 11
# ffl-components size: 31
# num of nodes: 19
# memory usage (MB): 1054.666752
# num of iterations: 12
# ffl-components size: 31
# num of nodes: 21
# memory usage (MB): 1054.666752
# num of iterations: 13
# ffl-components size: 31
# num of nodes: 24
# memory usage (MB): 1054.666752
# num of iterations: 14
# ffl-components size: 31
# num of nodes: 26
# memory usage (MB): 1054.666752
# num of iterations: 15
# ffl-components size: 31
# num of nodes: 26
# memory usage (MB): 1054.666752
# num of iterations: 16
# ffl-components size: 32
# num of nodes: 26
# memory usage (MB): 1054.666752
# num of iterations: 17
# ffl-components size: 32
# num of nodes: 28
# memory usage (MB): 1054.666752
# num of iterations: 18
# ffl-components size: 32
# num of nodes: 30
# memory usage (MB): 1054.666752
# num of iterations: 19
# ffl-components size: 32
# num of nodes: 32
# memory usage (MB): 1054.666752
# num of iterations: 20
# ffl-components size: 32
# num of nodes: 34
# memory usage (MB): 1054.666752
# num of iterations: 21
# ffl-components size: 32
# num of nodes: 34
# memory usage (MB): 1054.666752
# num of iterations: 22
# ffl-components size: 33
# num of nodes: 34
# memory usage (MB): 1054.666752
# num of iterations: 23
# ffl-components size: 33
# num of nodes: 34
# memory usage (MB): 1054.666752
# num of iterations: 24
# ffl-components size: 33
# num of nodes: 34
# memory usage (MB): 1054.666752
# num of iterations: 25
# ffl-components size: 33
# num of nodes: 34
# memory usage (MB): 1054.666752
# num of iterations: 26
# ffl-components size: 33
# num of nodes: 34
# memory usage (MB): 1054.666752
# num of iterations: 27
# ffl-components size: 33
# num of nodes: 34
# memory usage (MB): 1054.666752
# num of iterations: 28
# ffl-components size: 33
# num of nodes: 36
# memory usage (MB): 1054.666752
# num of iterations: 29
# ffl-components size: 33
# num of nodes: 36
# memory usage (MB): 1054.666752
# num of iterations: 30
# ffl-components size: 33
# num of nodes: 36
# memory usage (MB): 1054.666752
# num of iterations: 31
# ffl-components size: 33
# num of nodes: 39
# memory usage (MB): 1054.666752
# num of iterations: 32
# ffl-components size: 33
# num of nodes: 41
# memory usage (MB): 1054.666752
# num of iterations: 33
# ffl-components size: 33
# num of nodes: 41
# memory usage (MB): 1054.666752
# num of iterations: 34
# ffl-components size: 33
# num of nodes: 41
# memory usage (MB): 1054.666752
# num of iterations: 35
# ffl-components size: 33
# num of nodes: 41
# memory usage (MB): 1054.666752
# num of iterations: 36
# ffl-components size: 34
# num of nodes: 41
# memory usage (MB): 1054.666752
# num of iterations: 37
# ffl-components size: 34
# num of nodes: 43
# memory usage (MB): 1054.666752
# num of iterations: 38
# ffl-components size: 35
# num of nodes: 43
# memory usage (MB): 1054.666752
# num of iterations: 39
# ffl-components size: 35
# num of nodes: 43
# memory usage (MB): 1054.666752
# num of iterations: 40
# ffl-components size: 35
# num of nodes: 43
# memory usage (MB): 1054.666752
# num of iterations: 41
# ffl-components size: 35
# num of nodes: 45
# memory usage (MB): 1054.666752
# num of iterations: 42
# ffl-components size: 36
# num of nodes: 45
# memory usage (MB): 1054.666752
# num of iterations: 43
# ffl-components size: 36
# num of nodes: 45
# memory usage (MB): 1054.666752
# num of iterations: 44
# ffl-components size: 36
# num of nodes: 45
# memory usage (MB): 1054.666752
# num of iterations: 45
# ffl-components size: 36
# num of nodes: 47
# memory usage (MB): 1054.666752
# num of iterations: 46
# ffl-components size: 36
# num of nodes: 49
# memory usage (MB): 1054.666752
# num of iterations: 47
# ffl-components size: 36
# num of nodes: 51
# memory usage (MB): 1054.666752
# num of iterations: 48
# ffl-components size: 36
# num of nodes: 51
# memory usage (MB): 1054.666752
# num of iterations: 49
# ffl-components size: 36
# num of nodes: 51
# memory usage (MB): 1054.666752
# num of iterations: 50
# ffl-components size: 36
# num of nodes: 51
# memory usage (MB): 1054.666752
# num of iterations: 51
# ffl-components size: 36
# num of nodes: 51
# memory usage (MB): 1054.666752
# num of iterations: 52
# ffl-components size: 36
# num of nodes: 53
# memory usage (MB): 1054.666752
# num of iterations: 53
# ffl-components size: 36
# num of nodes: 55
# memory usage (MB): 1054.666752
# num of iterations: 54
# ffl-components size: 36
# num of nodes: 55
# memory usage (MB): 1054.666752
# num of iterations: 55
# ffl-components size: 37
# num of nodes: 55
# memory usage (MB): 1054.666752
# num of iterations: 56
# ffl-components size: 37
# num of nodes: 57
# memory usage (MB): 1054.666752
# num of iterations: 57
# ffl-components size: 37
# num of nodes: 59
# memory usage (MB): 1054.666752
# num of iterations: 58
# ffl-components size: 37
# num of nodes: 62
# memory usage (MB): 1054.666752
# num of iterations: 59
# ffl-components size: 37
# num of nodes: 64
# memory usage (MB): 1054.666752
# num of iterations: 60
# ffl-components size: 37
# num of nodes: 64
# memory usage (MB): 1054.666752
# num of iterations: 61
# ffl-components size: 37
# num of nodes: 64
# memory usage (MB): 1054.666752
# num of iterations: 62
# ffl-components size: 37
# num of nodes: 64
# memory usage (MB): 1054.666752
# num of iterations: 63
# ffl-components size: 37
# num of nodes: 66
# memory usage (MB): 1054.666752
# num of iterations: 64
# ffl-components size: 37
# num of nodes: 71
# memory usage (MB): 1054.666752
# num of iterations: 65
# ffl-components size: 38
# num of nodes: 71
# memory usage (MB): 1054.666752
# num of iterations: 66
# ffl-components size: 38
# num of nodes: 73
# memory usage (MB): 1054.666752
# num of iterations: 67
# ffl-components size: 38
# num of nodes: 75
# memory usage (MB): 1054.666752
# num of iterations: 68
# ffl-components size: 38
# num of nodes: 75
# memory usage (MB): 1054.666752
# num of iterations: 69
# ffl-components size: 38
# num of nodes: 77
# memory usage (MB): 1054.666752
# num of iterations: 70
# ffl-components size: 38
# num of nodes: 77
# memory usage (MB): 1054.666752
# num of iterations: 71
# ffl-components size: 38
# num of nodes: 79
# memory usage (MB): 1054.666752
# num of iterations: 72
# ffl-components size: 39
# num of nodes: 79
# memory usage (MB): 1054.666752
# num of iterations: 73
# ffl-components size: 39
# num of nodes: 81
# memory usage (MB): 1054.666752
# num of iterations: 74
# ffl-components size: 40
# num of nodes: 81
# memory usage (MB): 1054.666752
# num of iterations: 75
# ffl-components size: 40
# num of nodes: 81
# memory usage (MB): 1054.666752
# num of iterations: 76
# ffl-components size: 41
# num of nodes: 81
# memory usage (MB): 1054.666752
# num of iterations: 77
# ffl-components size: 41
# num of nodes: 83
# memory usage (MB): 1054.666752
# num of iterations: 78
# ffl-components size: 42
# num of nodes: 83
# memory usage (MB): 1054.666752
# num of iterations: 79
# ffl-components size: 42
# num of nodes: 85
# memory usage (MB): 1054.666752
# num of iterations: 80
# ffl-components size: 42
# num of nodes: 88
# memory usage (MB): 1054.666752
# num of iterations: 81
# ffl-components size: 42
# num of nodes: 92
# memory usage (MB): 1054.666752
# num of iterations: 82
# ffl-components size: 42
# num of nodes: 92
# memory usage (MB): 1054.666752
# num of iterations: 83
# ffl-components size: 42
# num of nodes: 92
# memory usage (MB): 1054.666752
# num of iterations: 84
# ffl-components size: 42
# num of nodes: 94
# memory usage (MB): 1054.666752
# num of iterations: 85
# ffl-components size: 42
# num of nodes: 94
# memory usage (MB): 1054.666752
# num of iterations: 86
# ffl-components size: 42
# num of nodes: 96
# memory usage (MB): 1054.666752
# num of iterations: 87
# ffl-components size: 42
# num of nodes: 98
# memory usage (MB): 1054.666752
# num of iterations: 88
# ffl-components size: 42
# num of nodes: 98
# memory usage (MB): 1054.666752
# num of iterations: 89
# ffl-components size: 42
# num of nodes: 100
# memory usage (MB): 1054.666752
# num of iterations: 90
# ffl-components size: 42
# num of nodes: 100
# memory usage (MB): 1054.666752
# num of iterations: 91
# ffl-components size: 42
# num of nodes: 103
# memory usage (MB): 1054.666752
# num of iterations: 92
# ffl-components size: 42
# num of nodes: 107
# memory usage (MB): 1054.666752
# {'021C': 1760, '021D': 1743, '021U': 789, '030C': 0, '030T': 151}
# []
# growth_barabasi: 0.3
# ffl_perc: 0.2781456953642384
# links_per_node: 3.0
# Network has been successfully generated!
# Total time spent: 0:00:11.232644

# %%
#from scipy import sparse
#s_ecoli = sparse.csr_matrix(interaction_matrix_ecoli)
#collect_topological_parameters(s_ecoli)
#ecoli_matrix_test = np.array(s_ecoli)
#test_matrix = sparse.csr_matrix.toarray(s_ecoli)

# %%
list_with_stats = list(dict_with_stats.values())
csv_columns = ['size','nucleus_size', 'sparsity', 'shortest_path', 'diameter', 'growth_pace', 'barabasi', 'ffl_perc', 'time_spent']
list_with_stats.insert(0,csv_columns)

with open("../networks/topology_stats.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(list_with_stats)

# %%
topology_data = pd.read_csv("../networks/topology_stats.csv",header=0, delimiter=",")
topology_data
# Out:
#    size  nucleus_size  sparsity  shortest_path  diameter  growth_pace  \
# 0   150            30       3.0         2.6787         4          0.4
# 1   200            30       3.0         2.7521         5          0.4
# 2   250            30       3.0         2.8338         5          0.4
#
#    barabasi  ffl_perc      time_spent
# 0       0.3  0.333333  0:00:09.912201
# 1       0.3  0.288557  0:00:10.944655
# 2       0.3  0.254980  0:00:13.050742

# %%
topology_data = pd.read_csv("../networks/topology_stats.csv",header=0, delimiter=",")
topology_data
# Out:
#     size  nucleus_size  sparsity  shortest_path  diameter  growth_pace  \
# 0    150            30  7.644860         2.3812         4          0.1
# 1    150            30  5.300000         2.8230         5          0.1
# 2    150            30  3.878049         2.8983         5          0.1
# 3    150            30  3.522727         3.0113         6          0.1
# 4    150            30  2.916667         3.1590         6          0.1
# 5    150            30  2.542857         3.1715         7          0.1
# 6    150            30  2.193548         3.3288         7          0.1
# 7    150            30  2.161290         3.3879         7          0.1
# 8    150            30  1.900000         3.4859         8          0.1
# 9    150            30  1.870968         3.7312         7          0.1
# 10   150            30  1.677419         3.8847         9          0.1
# 11   150            30  2.692857         2.3032         5          0.6
# 12   150            30  2.590361         2.6866         5          0.6
# 13   150            30  2.341463         2.9210         6          0.6
# 14   150            30  2.206897         3.3052         8          0.6
# 15   150            30  2.020408         3.2527         6          0.6
# 16   150            30  2.128205         3.3499         8          0.6
# 17   150            30  1.909091         3.5951         8          0.6
# 18   150            30  1.906977         3.3781         8          0.6
# 19   150            30  1.852941         3.4583         8          0.6
# 20   150            30  1.718750         3.7632         9          0.6
# 21   150            30  1.677419         3.8847         9          0.6
# 22   150            30  1.992908         2.3413         6          0.9
# 23   150            30  2.000000         2.9631         8          0.9
# 24   150            30  2.011494         2.7771         7          0.9
# 25   150            30  1.894737         3.3896         8          0.9
# 26   150            30  1.854167         3.4051         8          0.9
# 27   150            30  1.813953         3.5442         8          0.9
# 28   150            30  1.813953         3.5551         8          0.9
# 29   150            30  1.800000         3.7629         9          0.9
# 30   150            30  1.743590         3.7370         9          0.9
# 31   150            30  1.714286         3.6356         9          0.9
# 32   150            30  1.677419         3.8847         9          0.9
#
#     barabasi      time_spent
# 0       0.01  0:09:30.777412
# 1       0.10  0:00:26.876021
# 2       0.20  0:00:10.374069
# 3       0.30  0:00:10.125607
# 4       0.40  0:00:08.715911
# 5       0.50  0:00:09.252426
# 6       0.60  0:00:08.894882
# 7       0.70  0:00:08.283033
# 8       0.80  0:00:08.030689
# 9       0.90  0:00:07.511712
# 10      0.99  0:00:07.505287
# 11      0.01  0:00:30.797553
# 12      0.10  0:00:13.625903
# 13      0.20  0:00:11.686410
# 14      0.30  0:00:09.457454
# 15      0.40  0:00:08.093394
# 16      0.50  0:00:08.077602
# 17      0.60  0:00:08.101165
# 18      0.70  0:00:08.183682
# 19      0.80  0:00:08.249151
# 20      0.90  0:00:08.283383
# 21      0.99  0:00:08.913853
# 22      0.01  0:00:19.931318
# 23      0.10  0:00:12.994168
# 24      0.20  0:00:11.089086
# 25      0.30  0:00:08.781096
# 26      0.40  0:00:08.936946
# 27      0.50  0:00:08.361384
# 28      0.60  0:00:08.314252
# 29      0.70  0:00:08.378969
# 30      0.80  0:00:08.139515
# 31      0.90  0:00:08.962404
# 32      0.99  0:00:07.881635

# %%
topology_data['shortest_path'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualize network

# %%
def read_df_as_network(filename):
    with open(filename, 'rt') as f:
        network_df = pd.read_csv(f, sep=' ', header = None)
        network = nx.from_pandas_edgelist(network_df, create_using=nx.DiGraph(), source = 0, target = 1)
        return network
    
network_test = read_df_as_network(os.path.join(ART_NET_PATH, "test.tsv"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-02271a6f364d> in <module>
#       5         return network
#       6
# ----> 7 network_test = read_df_as_network(os.path.join(ART_NET_PATH, "test.tsv"))
#
# NameError: name 'os' is not defined

# %%
print(len(network_test.nodes))
# Out:
# 300

# %% [markdown]
# ### Network

# %%
nx.draw(network_test, node_size = 5, edge_color = 'gray')

# %%
# def list_to_dictionary(your_list):
    
#     from collections import defaultdict
    
#     d = defaultdict(list)

#     for key, value in your_list:
#         d[key].append(value)
        
#     return d

# def get_degree_values(network):
    
#     in_degree_list = list_to_dictionary(list(network_test.in_degree()))
#     out_degree_list = list_to_dictionary(list(network_test.out_degree()))

#     return in_degree_list.keys(), np.concatenate(list(in_degree_list.values())),\
#     np.concatenate(list(out_degree_list.values()))

# nodes, in_degree, out_degree = get_degree_values(network_test)
# print(list(nodes))
# print(in_degree/sum(in_degree))
# print(out_degree/sum(out_degree))

# in_probs = pd.Series(nodes, in_degree/sum(in_degree))
# out_probs = pd.Series(nodes, out_degree/sum(out_degree))

# %% [markdown]
# ### Minimum spanning tree

# %%
tree = nx.minimum_spanning_tree(network_test)
nx.draw(tree, node_size = 5, edge_color = 'gray')
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# <ipython-input-13-1c9410794d1b> in <module>
# ----> 1 tree = nx.minimum_spanning_tree(network_test)
#       2 nx.draw(tree, node_size = 5, edge_color = 'gray')
#
# ~/anaconda3/envs/python_env/lib/python3.7/site-packages/networkx/algorithms/tree/mst.py in minimum_spanning_tree(G, weight, algorithm, ignore_nan)
#     542     """
#     543     edges = minimum_spanning_edges(
# --> 544         G, algorithm, weight, keys=True, data=True, ignore_nan=ignore_nan
#     545     )
#     546     T = G.__class__()  # Same graph class as G
#
# <decorator-gen-690> in minimum_spanning_edges(G, algorithm, weight, keys, data, ignore_nan)
#
# ~/anaconda3/envs/python_env/lib/python3.7/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      74         if match:
#      75             msg = f"not implemented for {' '.join(graph_types)} type"
# ---> 76             raise nx.NetworkXNotImplemented(msg)
#      77         else:
#      78             return not_implement_for_func(*args, **kwargs)
#
# NetworkXNotImplemented: not implemented for directed type

# %%
nx.diameter(network_test)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-14-7e675922dd7e> in <module>
# ----> 1 nx.diameter(network_test)
#
# ~/anaconda3/envs/python_env/lib/python3.7/site-packages/networkx/algorithms/distance_measures.py in diameter(G, e, usebounds)
#     297         return extrema_bounding(G, compute="diameter")
#     298     if e is None:
# --> 299         e = eccentricity(G)
#     300     return max(e.values())
#     301
#
# ~/anaconda3/envs/python_env/lib/python3.7/site-packages/networkx/algorithms/distance_measures.py in eccentricity(G, v, sp)
#     262             else:
#     263                 msg = "Found infinite path length because the graph is not" " connected"
# --> 264             raise nx.NetworkXError(msg)
#     265
#     266         e[n] = max(length.values())
#
# NetworkXError: Found infinite path length because the digraph is not strongly connected

# %%
nx.average_shortest_path_length(network_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-e4867f09e568> in <module>
# ----> 1 nx.average_shortest_path_length(network_test)
#
# ~/anaconda3/envs/python_env/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/generic.py in average_shortest_path_length(G, weight, method)
#     384         return 0
#     385     # Shortest path length is undefined if the graph is disconnected.
# --> 386     if G.is_directed() and not nx.is_weakly_connected(G):
#     387         raise nx.NetworkXError("Graph is not weakly connected.")
#     388     if not G.is_directed() and not nx.is_connected(G):
#
# AttributeError: 'list' object has no attribute 'is_directed'

# %%
degrees = [network_test.degree(n) for n in network_test.nodes()]
print(statistics.mean(degrees))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-8dc3348235c4> in <module>
# ----> 1 degrees = [network_test.degree(n) for n in network_test.nodes()]
#       2 print(statistics.mean(degrees))
#
# AttributeError: 'list' object has no attribute 'nodes'

# %%
plt.figure(figsize=(15, 10), dpi=80)
network_test = [d for n, d in network_test.degree]
plt.hist(network_test, bins=100, alpha=0.75)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-819203144dc3> in <module>
#       1 plt.figure(figsize=(15, 10), dpi=80)
# ----> 2 network_test = [d for n, d in network_test.degree]
#       3 plt.hist(network_test, bins=100, alpha=0.75)
#
# AttributeError: 'list' object has no attribute 'degree'
